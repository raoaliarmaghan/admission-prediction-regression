# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
admpre = pd.read_csv('E:\study\ITU AI-ML COURSE\Admission_prediction.csv')

# %%
admpre.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
admpre.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84

# %%
admpre.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
admpre.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
sns.pairplot(admpre)

# %%
sns.distplot(admpre['Chance of Admit '])

# %%
x = admpre[['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
       'LOR ', 'CGPA', 'Research']]
y = admpre['Chance of Admit ']

# %%
x.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0

# %%
y.head()
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: Chance of Admit , dtype: float64

# %%
admpre.count()
# Out:
# Serial No.           500
# GRE Score            500
# TOEFL Score          500
# University Rating    500
# SOP                  500
# LOR                  500
# CGPA                 500
# Research             500
# Chance of Admit      500
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.4)

# %%
x_train.count()
# Out:
# Serial No.           300
# GRE Score            300
# TOEFL Score          300
# University Rating    300
# SOP                  300
# LOR                  300
# CGPA                 300
# Research             300
# dtype: int64

# %%
x_test.count()
# Out:
# Serial No.           200
# GRE Score            200
# TOEFL Score          200
# University Rating    200
# SOP                  200
# LOR                  200
# CGPA                 200
# Research             200
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -1.2432980819321933

# %%
xcol = x.columns

# %%
corr_df = pd.DataFrame(lm.coef_, xcol, columns=['coefficient'])

corr_df
# Out:
#                    coefficient
# Serial No.            0.000103
# GRE Score             0.002050
# TOEFL Score           0.001691
# University Rating     0.004836
# SOP                   0.012033
# LOR                   0.013678
# CGPA                  0.120369
# Research              0.019679

# %%
prediction = lm.predict(x_test)

# %%
plt.scatter(y_test, prediction)

# %%
lm.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-02e5fb6e3d05> in <module>()
# ----> 1 lm.score(y_test,prediction)
#
# NameError: name 'lm' is not defined
